# %% [markdown]
# <a href="https://colab.research.google.com/github/Meera-Ajay-25/LGMVIP-DataScience/blob/main/LGMVIP_TASK_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***LETS GROW MORE***
#
# Data Science Internship (LGMVIP-SEPT 2021)
#
# **TASK 4**: Exloratory data analysis on global terrorism data
#
# By Meera Ajayakumar

# %% [markdown]
# **LOADING THE REQUIRED LIBRARIES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **READING THE DATA**

# %%
df = pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='ISO-8859-1',low_memory=False)
df.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  1.970000e+11   1970       7     2  ...        0         0       0      NaN
# 1  1.970000e+11   1970       0     0  ...        1         1       1      NaN
# 2  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
# 3  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
# 4  1.970010e+11   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# **CHECKING FOR NULL VALUES**

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# **DATA EXPLORATION**

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325955e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991020e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009020e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014080e+11    2014.000000  ...       0.000000       0.000000
# max    2.017120e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
df.rename(columns={'iyear':'year','imonth':'month','iday':'day','country_txt':'Country','region_txt':'Region','gname':'Group','city':'City','latitude':'latitude','longitude':'longitude','location':'location','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapontype','nkill':'Kill','nwound':'wound','motive':'motive','provstate':'state'},inplace=True)
df.head()
# Out:
#         eventid  year  month  day  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  1.970000e+11  1970      7    2  ...        0         0       0      NaN
# 1  1.970000e+11  1970      0    0  ...        1         1       1      NaN
# 2  1.970010e+11  1970      1    0  ...       -9         1       1      NaN
# 3  1.970010e+11  1970      1    0  ...       -9         1       1      NaN
# 4  1.970010e+11  1970      1    0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# **Data Vizualisation**

# %%
df.corr()
# Out:
#             eventid      year     month  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid    1.000000  0.999996  0.002705  ... -0.133252 -0.077851 -0.175606
# year       0.999996  1.000000  0.000139  ... -0.133253 -0.077847 -0.175596
# month      0.002705  0.000139  1.000000  ... -0.002034 -0.002554 -0.006336
# day        0.018270  0.018254  0.005497  ... -0.001621 -0.002027 -0.001199
# extended   0.091762  0.091754 -0.000468  ...  0.075147  0.027335  0.080767
# ...             ...       ...       ...  ...       ...       ...       ...
# nreleased -0.181613 -0.181556 -0.011535  ...  0.040947  0.085055  0.064759
# INT_LOG   -0.143600 -0.143601 -0.002302  ...  0.996211  0.052537  0.891051
# INT_IDEO  -0.133252 -0.133253 -0.002034  ...  1.000000  0.082014  0.893811
# INT_MISC  -0.077851 -0.077847 -0.002554  ...  0.082014  1.000000  0.252193
# INT_ANY   -0.175606 -0.175596 -0.006336  ...  0.893811  0.252193  1.000000
#
# [77 rows x 77 columns]

# %% [markdown]
# **TERRORIST ATTACKS IN EACH YEAR**

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='year',data=df,palette='pastel')
plt.xticks(rotation=90,fontsize=12)
plt.title('Terrorist Attack Each Year')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# From the above graph we can say that most number of attacks happened in the year **2014** followed by **2015** and **2016**

# %% [markdown]
# **COUNTRIES WITH HIGHEST NUMBER OF ATTACKS**

# %%
a=df['Country'].value_counts().head(20).sort_values(ascending=False).reset_index()
sns.set_style('darkgrid')
plt.figure(figsize=(10,5))
sns.barplot(x=a['index'],y=a['Country'],palette='gist_rainbow')
plt.xticks(rotation=90,fontsize=13)
plt.title('Attack on countries',fontsize=25)
plt.xlabel('Countries',fontsize=15,color='g')
plt.ylabel('Number of attack',fontsize=15,color='g')
plt.show()

# %% [markdown]
# **Iran** is the country where the most attacks have happened so far. After Iran, **Pakistan** & **Afghanistan** are the countries where most attacks have happened.**India** is in **4th** place in most attacked countries.

# %% [markdown]
# **REGION-WISE ATTACKS**

# %%
pd.crosstab(df.year, df.Region).plot(kind='area',stacked=False,figsize=(20,6))
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=15)
plt.xlabel("Year",fontsize=15)
plt.show()

# %%
plt.subplots(figsize=(15,5))
sns.countplot(y=df["Region"],data=df,order=df.Region.value_counts()[0:10].index,palette="BrBG")

# %% [markdown]
# Middle East & North Africa are the region where the most number of attacks have happened.South Asia is in 2nd place in the list of most attacked region.Australasia & Oceania are the region with least number of attacks.

# %% [markdown]
# **ATTACK ON CITIES**

# %%
a=df['City'].value_counts().reset_index().head(20)
plt.figure(figsize=(10,5))
sns.barplot(x=a['index'],y=a['City'],palette="Set2")
plt.xticks(rotation=90,fontsize=13)
plt.title('Attack on City',fontsize=25)
plt.xlabel('City',fontsize=15,color='r')
plt.ylabel('Number of attack',fontsize=15,color='r')
plt.show()

# %% [markdown]
# City with highest Terrorist Attack is **Baghdad**

# %% [markdown]
# **BAR PLOT TO SHOW GANGS INVLOVED IN THE ATTACKS**

# %%
df['Group'].value_counts().to_frame().drop('Unknown').head(15).plot(kind='bar',color="purple",figsize=(15,5))
plt.title("Top 15 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("No. of attacks",fontsize=15)
plt.show()

# %% [markdown]
# **Taliban** is the most active Terrorist group

# %% [markdown]
# **TYPES OF ATTACKS**

# %%
plt.subplots(figsize=(7,5))
sns.countplot(x="Attacktype",data=df,order=df.Attacktype.value_counts().index,palette='flag')
plt.xticks(rotation=90)
plt.title("Types of Attack")
# Out:
# Text(0.5, 1.0, 'Types of Attack')

# %% [markdown]
# **Bombing/Explosion** have the highest count whereas **Hijacking** is the least

# %% [markdown]
# **CONCLUSIONS**
# Country with the most attacks: **Iraq**
#
# Region with the most attacks: **Middle East & North Africa**
#
# City with the most attacks: **Baghdad**
#
# Year with the most attacks: **2014**
#
# Group with the most attacks: **Taliban**
#
# Highest Attack Types: **Bombing/Explosion**
#
# **THANK YOU!!!**
